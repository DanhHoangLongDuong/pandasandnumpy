# %%
import numpy as np
import pandas as pd

# %%
my_series = pd.Series([np.nan] * 5)
my_series
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# dtype: float64

# %%
my_series.isna()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
my_series.isna().sum()
# Out:
# np.int64(5)
