# %%
import pandas as pd

# %% [markdown]
# add chart title and axis labels to increase understanding

# %%
transactions = pd.read_csv("../retailFiles/transactions.csv")
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.loc[:, ["transactions"]].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
chart_img = transactions.loc[transactions["store_nbr"] == 47, ["transactions"]].plot.hist()
chart_img
# Out:
# <Axes: ylabel='Frequency'>

# %%
chart_img.figure.savefig("chart_img_exp.png", bbox_inches="tight")
