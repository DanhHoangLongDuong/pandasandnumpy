# %%
import numpy as np
import pandas as pd

# %% [markdown]
# add ";" show that "<AxesSubplot> does not shown"
#
# sales_df.set_index("date").plot() : This set 'date' as the index before plotting the chart
# == sales_df.plot(x="date") : This sets 'date' as the x-axis in the .plot() parameters
#
# sales_df.set_index("date").loc[:, "grocery"].plot() : this filters the 'grocery' column before plotting the chart == sales_df.plot(x="date", y="grocery") : This plots 'grocery' values along the y-axis

# %%
transactions = pd.read_csv("../retailFiles/transactions.csv", parse_dates=["date"]) #parse_dates to store date column as datetime datatype
transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.plot()
# Out:
# <Axes: >

# %%
transactions.set_index("date").loc["2013-01", "transactions"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
#only store number 44
transactions.query("store_nbr == 44").set_index("date").loc["2013-01", "transactions"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions_44 = transactions.loc[transactions["store_nbr"] == 44, ["date", "transactions"]]
transactions_44.head()
# Out:
#           date  transactions
# 38  2013-01-02          4821
# 84  2013-01-03          3618
# 130 2013-01-04          4169
# 176 2013-01-05          4921
# 222 2013-01-06          4925

# %%
transactions_44.set_index("date").plot()
# Out:
# <Axes: xlabel='date'>

# %%
transactions_44.plot(x="date", y="transactions")
# Out:
# <Axes: xlabel='date'>

# %%
(transactions
    .query("store_nbr in [44, 47]")
    .pivot_table(index="date", columns="store_nbr")
    .droplevel(0, axis=1)
    .plot()
);
