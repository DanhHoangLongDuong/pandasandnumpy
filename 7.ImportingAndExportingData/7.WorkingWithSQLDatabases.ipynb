# %%
import pandas as pd

# %%
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine("sqlite:///../soccer_database.sqlite") # Database From machine
inspect(engine).get_table_names() # show tables name

# %%
pd.read_sql("SELECT * FROM player limit 5", engine) # Query by read_sql
