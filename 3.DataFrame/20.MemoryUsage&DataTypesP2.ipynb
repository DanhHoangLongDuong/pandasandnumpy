# %% [markdown]
# 3.Downcast numeric data
#
# Interger and floats are cast as 64-bit by default to handle any possible value, but you can downcast numeric data to a smaller bit size to save space if possible

# %% [markdown]
# 4.Using the categorical data type
