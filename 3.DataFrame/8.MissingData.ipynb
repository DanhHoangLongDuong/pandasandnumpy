# %%
import numpy as np
import pandas as pd

# %%
# .isna() method returns a DataFrame with Boolean values (True for NAs, False for others)
# .fillna(0) handle missing data by replacing them with other values
#e.g. product_df.fillna({"price": 0}) fill only price column NAs value with 0
#e.g. product_df.dropna(subset=["price"]) drop NAs value only on price column
