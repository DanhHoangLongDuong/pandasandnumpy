# %%
import pandas as pd
import numpy as np

# %%
sales_series = pd.Series([0, 5, 155, 0 ,518], index=['coffee', 'coffee', 'tea', 'coconut', 'sugar'], name='Sales')
sales_series
# Out:
# coffee       0
# coffee       5
# tea        155
# coconut      0
# sugar      518
# Name: Sales, dtype: int64
