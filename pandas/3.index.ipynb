# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(range(5))
my_series
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_series[3]
# Out:
# np.int64(3)

# %%
my_series[1::2]
# Out:
# 1    1
# 3    3
# dtype: int64

# %%
my_series = pd.Series(range(5), index=["day0", "day1", "day2", "day3", "day4"])
my_series
# Out:
# day0    0
# day1    1
# day2    2
# day3    3
# day4    4
# dtype: int64

# %%
my_series["day2"]
# Out:
# np.int64(2)

# %%
my_series[::2]
# Out:
# day0    0
# day2    2
# day4    4
# dtype: int64
