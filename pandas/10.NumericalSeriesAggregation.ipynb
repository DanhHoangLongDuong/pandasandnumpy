# %%
import pandas as pd
import numpy as np

# %%
sales_series = pd.Series([0.0, 5.0, 155.0, np.nan, 518.0], index=['coffee', 'coffee', 'tea', 'coconut', 'sugar'], name='Sales')
sales_series
# Out:
# coffee       0.0
# coffee       5.0
# tea        155.0
# coconut      NaN
# sugar      518.0
# Name: Sales, dtype: float64

# %%
sales_series.sum()
# Out:
# np.float64(678.0)

# %%
sales_series.loc['coffee'].sum()
# Out:
# np.float64(5.0)

# %%
# .quantile(): Returns a specified percentile, or list of percentiles
sales_series.quantile([0.25, 0.50, 0.75])
# Out:
# 0.25      3.75
# 0.50     80.00
# 0.75    245.75
# Name: Sales, dtype: float64

# %%
sales_series.quantile([0.5], interpolation="nearest")
# Out:
# 0.5    155.0
# Name: Sales, dtype: float64
