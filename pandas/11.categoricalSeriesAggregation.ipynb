# %%
import pandas as pd
import numpy as np

# %%
items = pd.Series(['coffee', 'coffee', 'tea', 'coconut', 'sugar'])
items
# Out:
# 0     coffee
# 1     coffee
# 2        tea
# 3    coconut
# 4      sugar
# dtype: object

# %%
items.value_counts()
# Out:
# coffee     2
# tea        1
# coconut    1
# sugar      1
# Name: count, dtype: int64

# %%
items.value_counts(normalize=True) #return  the percentage of total for each category
# Out:
# coffee     0.4
# tea        0.2
# coconut    0.2
# sugar      0.2
# Name: proportion, dtype: float64

# %%
items.unique() #Show unique objects
# Out:
# array(['coffee', 'tea', 'coconut', 'sugar'], dtype=object)

# %%
items.nunique() #Count unique objects
# Out:
# 4

# %%
string_series = pd.Series(['day 0', 'day 0', 'day 2', 'day 2', 'day 4'])
string_series
# Out:
# 0    day 0
# 1    day 0
# 2    day 2
# 3    day 2
# 4    day 4
# dtype: object

# %%
string_series.nunique()
# Out:
# 3

# %%
string_series.unique()
# Out:
# array(['day 0', 'day 2', 'day 4'], dtype=object)

# %%
string_series.value_counts(normalize=True)
# Out:
# day 0    0.4
# day 2    0.4
# day 4    0.2
# Name: proportion, dtype: float64
