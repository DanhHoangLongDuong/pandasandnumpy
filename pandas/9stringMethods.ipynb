# %%
import pandas as pd
import numpy as np

# %%
string_series = pd.Series(["day 0", "day 1", "day 2", "day 3", "day 4"])
string_series
# Out:
# 0    day 0
# 1    day 1
# 2    day 2
# 3    day 3
# 4    day 4
# dtype: object

# %%
string_series.str.contains("1")
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
string_series.str.upper()
# Out:
# 0    DAY 0
# 1    DAY 1
# 2    DAY 2
# 3    DAY 3
# 4    DAY 4
# dtype: object

# %%
string_series.str[-1]
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: object

# %%
string_series.str.split(' ')
# Out:
# 0    [day, 0]
# 1    [day, 1]
# 2    [day, 2]
# 3    [day, 3]
# 4    [day, 4]
# dtype: object

# %%
string_series.str.split(' ', expand=True) #expand=True: expand items in lists into their own column
# Out:
#      0  1
# 0  day  0
# 1  day  1
# 2  day  2
# 3  day  3
# 4  day  4
