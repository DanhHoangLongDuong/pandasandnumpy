# %%
import numpy as np

rng = np.random.default_rng(616)

inventory = rng.integers(0, 100, 10)

inventory

# %%
price = (rng.random(10) * 10).round(2)
price

# %%
price * inventory

# %%
#Assignment
prices = np.array([5.99, 6.99, 22.49, 99.99, 4.99, 49.99])

total = prices + 5
total
# Out:
# array([ 10.99,  11.99,  27.49, 104.99,   9.99,  54.99])

# %%
discount_pct = rng.random(6)
pct_owed = 1 - discount_pct
final_owed = pct_owed * total

print(discount_pct)
print(pct_owed)
print(final_owed.round(2))
# Out:
# [0.98150375 0.54986705 0.50866454 0.22631697 0.01686436 0.8520208 ]
# [0.01849625 0.45013295 0.49133546 0.77368303 0.98313564 0.1479792 ]
# [ 0.2   5.4  13.51 81.23  9.82  8.14]
