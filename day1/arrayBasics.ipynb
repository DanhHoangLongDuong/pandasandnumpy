# %%
import numpy as np

my_list = [x * 10 for x in range (1, 11)]

list = np.array(my_list)
print(list)

# %%
print(f"ndim: {list.ndim}")
print(f"shape: {list.shape}")
print(f"size: {list.size}")
print(f"dtype: {list.dtype}")
