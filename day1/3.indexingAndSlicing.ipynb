# %%
import numpy as np

# %%
integer_array = np.arange(12)
integer_array
integer_array[2]
integer_array[:5]
integer_array[::2]
new_array = integer_array.reshape(3, 4)
new_array[:,:]
new_array[1:, :]
new_array[:, 3]
