# %%
import numpy as np

ages = np.array([1, 2, 3, 4, 5])

#scalar value representing an age increment
scalar_value = 1

updated_ages = ages + scalar_value
updated_ages
# Out:
# array([2, 3, 4, 5, 6])
