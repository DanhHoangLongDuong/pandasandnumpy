# %%
import numpy as np

rng = np.random.default_rng(12345)

randomArray = (rng.random(10) * 10).reshape(2, 5)
randomArray
# Out:
# array([[2.27336022, 3.1675834 , 7.97365457, 6.76254671, 3.91109551],
#        [3.32813928, 5.98308754, 1.86734186, 6.72756044, 9.41802865]])

# %%
randomArray.sum(axis=0)
# Out:
# array([ 5.6014995 ,  9.15067093,  9.84099643, 13.49010715, 13.32912416])

# %%
randomArray.sum()
# Out:
# np.float64(51.412398172043865)
